# %%
import numpy as np

# %% [markdown]
# # Softmax

# %%
a = np.random.randn(5)
expa = np.exp(a)
answer = expa / expa.sum()

# %%
answer
# Out:
# array([ 0.17181731,  0.16691466,  0.01239089,  0.28035338,  0.36852377])

# %%
A = np.random.randn(100, 5)
expA = np.exp(A)
answer = expA / expA.sum(axis = 1, keepdims=True)

# %%
answer.sum(axis=0)
# Out:
# array([ 19.50671126,  17.44768056,  20.08331911,  22.50389065,  20.45839842])

# %%
A[:,None]
# Out:
# array([[[-0.79743914, -1.45460735,  0.79139528, -0.18149945, -1.25231936]],
#
#        [[ 0.21328936,  1.99164594, -0.7730228 ,  0.53759246, -0.21959042]],
#
#        [[ 0.46077775,  0.96098056,  1.17059542, -1.42437888, -0.92096322]],
#
#        [[ 0.30504629,  1.6953667 ,  0.59509384,  1.57388889,  0.7523209 ]],
#
#        [[-0.131261  , -1.50681604, -0.89160143, -0.8560084 ,  0.69117833]],
#
#        [[ 0.95630748,  1.10859154,  1.65759873,  1.05483387,  0.42421163]],
#
#        [[ 0.42785309, -0.06539551, -0.36113577,  0.10973734,  1.47302047]],
#
#        [[ 0.53228118, -0.44468237,  0.78498586,  1.25011261,  0.72463955]],
#
#        [[ 0.63133801,  0.09213482,  0.49364178, -0.31609092, -0.50480568]],
#
#        [[ 0.39398648, -0.49586758,  0.29340092,  1.89817165, -0.96484195]],
#
#        [[ 0.06289483,  0.59944704, -0.12080017, -0.05089708,  0.44883209]],
#
#        [[ 0.11531491,  1.04556989,  1.07999998, -1.89799454, -0.28328383]],
#
#        [[-0.98286525, -0.1454357 ,  0.93837661, -1.03929881, -0.82085409]],
#
#        [[ 0.84462282,  0.24679677, -0.2725274 ,  0.31758346, -0.66179929]],
#
#        [[ 0.30981918, -0.73180553, -0.37011546,  0.51636464,  0.47846463]],
#
#        [[ 0.5806132 , -0.22548791,  0.78683382,  0.98100853, -0.76782213]],
#
#        [[ 0.31386654, -1.37257196, -0.79762134, -0.53958396,  1.20151511]],
#
#        [[ 0.63711577,  0.15327053, -1.34403873, -1.20213828,  1.47414228]],
#
#        [[-0.29757055, -0.70589184,  1.14842663,  0.64810177, -2.48779281]],
#
#        [[-0.28959459, -0.24762867,  0.74075681,  1.00512129,  1.5221592 ]],
#
#        [[-0.36721359,  0.09889524, -1.31586307,  0.1078164 ,  1.256434  ]],
#
#        [[ 0.60620486,  0.5220755 ,  1.40303223, -0.64231778,  1.50290175]],
#
#        [[ 0.42004631, -1.17875916, -0.04294883,  0.06400818,  0.41008185]],
#
#        [[ 0.59410066,  0.49342062,  1.03568866,  0.04386768,  0.92886819]],
#
#        [[-0.91390193,  0.72446953, -0.21019072, -0.96415712, -1.41850355]],
#
#        [[ 0.44643628,  0.83692855,  0.8866725 ,  3.01539716,  0.82113176]],
#
#        [[ 0.94231976,  1.59313475,  1.42305371, -1.24236386, -0.01015989]],
#
#        [[-0.65289713, -0.6715605 , -1.06393413,  0.68981608,  0.43618251]],
#
#        [[ 0.05759794, -0.02749477, -0.06049688, -0.45912664, -0.63689039]],
#
#        [[-1.3037983 , -0.2417949 , -0.57093004, -0.37970365,  0.50717818]],
#
#        [[ 0.50674473, -1.32675763,  2.19652656, -1.19608742,  2.22556289]],
#
#        [[-1.18374525, -0.84845654, -1.93183566,  1.24449565, -1.48814579]],
#
#        [[-0.13813644,  1.82656289,  1.28102822, -0.16367835, -0.45963571]],
#
#        [[-2.30936226,  1.27191826,  2.64785165, -0.22952522,  2.26257154]],
#
#        [[-2.79931897,  0.38351598, -0.09012746, -0.01181632,  1.40514662]],
#
#        [[-0.63053517,  0.08512472, -0.24694393,  0.19130242,  0.01750098]],
#
#        [[-0.74454779,  0.64444638,  0.89344167,  0.99509493,  0.69479776]],
#
#        [[ 1.2252408 ,  1.52538079, -0.46630811,  0.22498269,  0.41378227]],
#
#        [[-1.34743115, -0.74890614, -0.30167844,  0.09633632, -0.10624926]],
#
#        [[ 0.14026498, -1.33433326, -0.05737657, -0.16421293, -0.58779024]],
#
#        [[ 0.21578824, -1.39895175, -2.16123561, -1.30349483, -0.01281096]],
#
#        [[-0.24758587,  0.54229624, -0.89095768,  2.18753508, -0.68083203]],
#
#        [[-0.69720034, -0.23452618, -0.12979226,  1.42908529, -0.23851417]],
#
#        [[-1.11280996, -0.57232465,  0.51235372, -0.57069382, -1.44573256]],
#
#        [[ 1.1884351 , -0.15811136, -0.77237611,  1.30491879,  0.76369958]],
#
#        [[ 2.36388351,  0.52195921,  1.64325502,  0.78763688,  0.97848554]],
#
#        [[ 0.37793728, -0.43393432,  0.31019122, -1.39316544, -0.48600284]],
#
#        [[ 0.72731758, -0.52370461, -1.72096756, -0.21130718,  0.59632031]],
#
#        [[ 0.10468853, -0.35126842, -0.33980523,  0.21330792, -0.72236038]],
#
#        [[-0.6431804 , -0.58360983, -0.07778694,  0.90425382, -0.5141251 ]],
#
#        [[-0.6830857 , -1.43167511,  1.19767886,  0.33012065,  0.83817025]],
#
#        [[ 0.04617769, -1.24513586,  0.84354371,  0.00916255,  1.28210017]],
#
#        [[-0.1155601 ,  0.25066483,  1.29673423,  0.47757421,  1.22605512]],
#
#        [[ 0.05577419, -0.60630334, -0.84436379, -1.69861728, -1.2171238 ]],
#
#        [[ 1.02832652,  0.23425459, -0.14037484,  1.62068367,  1.91852986]],
#
#        [[ 0.64608191,  0.10383682,  0.33653496, -0.12990009, -0.60183293]],
#
#        [[-1.69073024, -1.45657053, -0.43638302,  1.88631831,  0.57075694]],
#
#        [[-0.59013546, -0.6562246 , -0.03238721, -0.60389735, -2.00784865]],
#
#        [[ 1.48716383, -0.89092718,  1.17937415, -0.59611503, -0.49943553]],
#
#        [[ 0.28276977, -0.58707637, -0.27010349, -0.31031756, -1.02333459]],
#
#        [[ 1.23053486,  1.82565895, -0.39243717, -0.64311697,  1.16150262]],
#
#        [[-2.15609556, -0.25590237,  0.61077099, -0.11627302,  0.89821909]],
#
#        [[ 0.74365166,  0.83778617,  1.7048778 , -1.32949249,  0.39281472]],
#
#        [[ 1.34272996,  0.90247753, -1.90289181,  0.36948077, -1.24460496]],
#
#        [[ 0.86883745, -0.39365106,  0.80140055, -0.59530544, -0.42365328]],
#
#        [[-0.33284297, -0.57735621, -0.29195801, -1.6897503 ,  0.29322505]],
#
#        [[ 0.63964417,  0.56867843, -0.46446262,  0.55464858,  0.8936951 ]],
#
#        [[ 0.75569655, -1.27247752, -0.32572765, -1.02016471,  1.15917113]],
#
#        [[-1.90464545,  0.57689707, -0.4206765 ,  1.63655102, -0.61840187]],
#
#        [[ 0.29495478, -1.07286622, -0.45142259, -0.87201121,  1.88012199]],
#
#        [[-0.08815985, -0.21107784, -0.94920925,  0.26512807,  0.55816628]],
#
#        [[ 1.97358776,  0.49706058, -0.25966385,  1.43985686, -0.1359652 ]],
#
#        [[-0.70766471, -0.56353311, -1.28394851,  0.68373497,  0.10610032]],
#
#        [[-0.75168171,  0.97183081, -1.02099938,  0.66933668,  0.32158482]],
#
#        [[-0.4496852 , -0.07429771,  0.61236199, -0.06186922, -0.20435343]],
#
#        [[ 0.87558574, -0.44580074,  1.86760619, -0.53855698,  0.28932835]],
#
#        [[-1.99977999,  0.38176803,  0.68230136, -0.253609  ,  0.46503237]],
#
#        [[ 1.68306495,  2.22177032, -0.53396174,  0.39922032,  0.55652775]],
#
#        [[ 0.83284231,  1.17335817, -0.89498182,  0.43690607, -0.62760389]],
#
#        [[ 0.6577161 ,  0.71175081,  0.09589285, -0.26067193, -0.49610479]],
#
#        [[-0.4908342 , -0.50677498,  0.28885072,  3.98778972,  0.41344084]],
#
#        [[-0.7217045 ,  0.17353607, -1.04161132,  0.50271905,  0.61439308]],
#
#        [[ 2.88444876,  2.38252997,  0.06447447, -0.97704074, -0.30017774]],
#
#        [[-1.41543505, -0.30132582,  0.30429628, -2.18727359, -0.70376182]],
#
#        [[-0.91756587, -0.54360526,  1.52588455,  0.89963752,  0.87803314]],
#
#        [[ 0.04093121, -0.39830017, -1.1396319 ,  0.43982453,  0.42648335]],
#
#        [[ 1.40366462, -0.99892768,  0.02065066, -0.33154535,  0.11815616]],
#
#        [[ 0.49729101, -0.66124977,  0.66882331, -0.1825321 , -0.34262031]],
#
#        [[-0.23686105,  0.03854583,  0.81774435,  2.48633297, -1.75470335]],
#
#        [[ 2.32175511,  0.54856987,  0.40816725, -0.01901165,  0.38232707]],
#
#        [[ 1.25847972, -0.75801579,  0.22715489,  0.3178141 , -1.07508494]],
#
#        [[-0.87265886, -0.71564172,  1.49808817,  0.61493707,  1.00158215]],
#
#        [[-1.41661114,  0.16300653, -1.08240399,  0.84475974,  0.50741407]],
#
#        [[-2.32398251, -0.53126162, -0.62979229,  0.46137923,  1.39236631]],
#
#        [[ 0.19072434,  1.52908631,  1.07513293, -0.09501809,  0.3238739 ]],
#
#        [[-2.17406265,  0.97210754, -2.50209601,  1.28652333, -0.86274047]],
#
#        [[ 1.21088543, -2.05152984,  0.9116752 , -1.39287396, -0.97493815]],
#
#        [[ 2.08365663,  0.99406486,  0.778574  ,  0.38887426,  1.5163279 ]],
#
#        [[-1.79642937,  1.09358586,  0.3417782 , -0.01505667, -0.61151725]],
#
#        [[ 0.74988205, -0.16192238, -0.29243794,  3.19188018, -0.53037723]]])

# %% [markdown]
# # forwardprop

# %%
import matplotlib.pyplot as plt

# %%
Nclass = 500

#gaussian clouds
X1 = np.random.randn(Nclass, 2) + np.array([0, -2])
X2 = np.random.randn(Nclass, 2) + np.array([2, 2])
X3 = np.random.randn(Nclass, 2) + np.array([-2, 2])
plt.scatter( X[:,0])
